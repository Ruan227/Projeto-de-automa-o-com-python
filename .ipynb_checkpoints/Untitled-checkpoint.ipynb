# %%
import pandas as pd
tabela = pd.read_excel("carteira ruan indicacao cartao santander18.01 427 nomes.xlsx")
display(tabela)
# Out:
#                                 NOME           CPF   TELEFONE 1    TELEFONE 2
# 0    ELIANE SILVA DE AZEVEDO PEREIRA  1.394753e+09  75988378672  (75)36312034
# 1               JASONIA DA CONCEICAO  1.395704e+09  73999964311   73999961381
# 2            ELIAS MAXIMO DOS SANTOS  1.395906e+09  77999151092    7736149330
# 3              ACASSIO CARDOSO SILVA  1.396110e+09  77999258573    7736133507
# 4                IVONETE SOUZA NUNES  1.396142e+09  75982041191   75982040567
# ..                               ...           ...          ...           ...
# 422  JAQUELINE CAMARGO FONTOURA DIAS  9.610622e+10  67992109623   67999008273
# 423     LUCILENE ANITA PEREIRA SILVA  9.614331e+10  67996274113   67996141312
# 424          OZEAS FERREIRA DOS REIS  9.654908e+10  67991604545    6735214704
# 425               ANA ALVES DE SOUZA  9.708393e+10  67996716809   67981467261
# 426     JOCELY PEREIRA MENDES DUARTE  9.912510e+10  67998915710   67981654969
#
# [427 rows x 4 columns]

# %%
#leitura da tabela
import pandas as pd
tabela = pd.read_excel("carteira ruan indicacao cartao santander18.01 427 nomes.xlsx")

#cpf variavel   "coluna"
for i, cpf in enumerate(tabela["CPF"]):
    telefone = i, (tabela["TELEFONE 2"])
    #paigina web
    from selenium import webdriver

    navegador = webdriver.Chrome()
    navegador.get("https://www.abrasuacontasnt.com.br/indicacoes")

    #CLICK CARTAO
    navegador.find_element_by_xpath('//*[@id="forme-form"]/div[1]/div[2]/label/span').click()

    #CLICK CORRESPONDENTE 
    navegador.find_element_by_xpath('//*[@id="forme-form"]/div[3]/div[2]/label/span').click()
    #LOJA
    navegador.find_element_by_xpath('//*[@id="codigoCorrespondente"]').send_keys('54254')
     #TERMOS
    navegador.find_element_by_xpath('//*[@id="AceitaPoliticas"]').click()

     #MEU CPF
    navegador.find_element_by_xpath('//*[@id="CPFSocio"]').send_keys('014.794.541-09')
    #CPF DO CLIENTE 
    navegador.find_element_by_xpath('//*[@id="CPF"]').send_keys(cpf)

        #TELEFONE DO CLIENTE 
    navegador.find_element_by_xpath('//*[@id="Telefone"]').send_keys(str(telefone))
        #TERMOS
    navegador.find_element_by_xpath('//*[@id="AceitaPoliticas"]').click()
# Out:
# C:\Users\Rui\AppData\Local\Temp/ipykernel_10156/1471857528.py:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   navegador.find_element_by_xpath('//*[@id="forme-form"]/div[1]/div[2]/label/span').click()
# C:\Users\Rui\AppData\Local\Temp/ipykernel_10156/1471857528.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   navegador.find_element_by_xpath('//*[@id="forme-form"]/div[3]/div[2]/label/span').click()
# C:\Users\Rui\AppData\Local\Temp/ipykernel_10156/1471857528.py:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   navegador.find_element_by_xpath('//*[@id="codigoCorrespondente"]').send_keys('54254')
# C:\Users\Rui\AppData\Local\Temp/ipykernel_10156/1471857528.py:22: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   navegador.find_element_by_xpath('//*[@id="AceitaPoliticas"]').click()
# C:\Users\Rui\AppData\Local\Temp/ipykernel_10156/1471857528.py:25: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   navegador.find_element_by_xpath('//*[@id="CPFSocio"]').send_keys('014.794.541-09')
# C:\Users\Rui\AppData\Local\Temp/ipykernel_10156/1471857528.py:27: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   navegador.find_element_by_xpath('//*[@id="CPF"]').send_keys(cpf)
# C:\Users\Rui\AppData\Local\Temp/ipykernel_10156/1471857528.py:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   navegador.find_element_by_xpath('//*[@id="Telefone"]').send_keys(str(telefone))
# C:\Users\Rui\AppData\Local\Temp/ipykernel_10156/1471857528.py:32: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   navegador.find_element_by_xpath('//*[@id="AceitaPoliticas"]').click()
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10156/1471857528.py in <module>
#      10
#      11     navegador = webdriver.Chrome()
# ---> 12     navegador.get("https://www.abrasuacontasnt.com.br/indicacoes")
#      13
#      14     #CLICK CARTAO
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     434         Loads a web page in the current browser session.
#     435         """
# --> 436         self.execute(Command.GET, {'url': url})
#     437
#     438     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00FD9943+2595139]
# 	Ordinal0 [0x00F6C9F1+2148849]
# 	Ordinal0 [0x00E643F0+1065968]
# 	Ordinal0 [0x00E587C2+1017794]
# 	Ordinal0 [0x00E58FF8+1019896]
# 	Ordinal0 [0x00E5A892+1026194]
# 	Ordinal0 [0x00E54219+999961]
# 	Ordinal0 [0x00E65860+1071200]
# 	Ordinal0 [0x00EBB2D2+1422034]
# 	Ordinal0 [0x00EAB806+1357830]
# 	Ordinal0 [0x00E86086+1204358]
# 	Ordinal0 [0x00E86F96+1208214]
# 	GetHandleVerifier [0x0117B232+1658114]
# 	GetHandleVerifier [0x0123312C+2411516]
# 	GetHandleVerifier [0x0106F261+560433]
# 	GetHandleVerifier [0x0106E366+556598]
# 	Ordinal0 [0x00F7286B+2173035]
# 	Ordinal0 [0x00F775F8+2192888]
# 	Ordinal0 [0x00F776E5+2193125]
# 	Ordinal0 [0x00F811FC+2232828]
# 	BaseThreadInitThunk [0x7745FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77777A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77777A6E+238]
