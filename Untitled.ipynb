# %%
import pandas as pd
tabela = pd.read_excel("carteira ruan indicacao cartao santander18.01 427 nomes.xlsx")
display(tabela)
# Out:
#                                 NOME           CPF   TELEFONE 1    TELEFONE 2
# 0    ELIANE SILVA DE AZEVEDO PEREIRA  1.394753e+09  75988378672  (75)36312034
# 1               JASONIA DA CONCEICAO  1.395704e+09  73999964311   73999961381
# 2            ELIAS MAXIMO DOS SANTOS  1.395906e+09  77999151092    7736149330
# 3              ACASSIO CARDOSO SILVA  1.396110e+09  77999258573    7736133507
# 4                IVONETE SOUZA NUNES  1.396142e+09  75982041191   75982040567
# ..                               ...           ...          ...           ...
# 422  JAQUELINE CAMARGO FONTOURA DIAS  9.610622e+10  67992109623   67999008273
# 423     LUCILENE ANITA PEREIRA SILVA  9.614331e+10  67996274113   67996141312
# 424          OZEAS FERREIRA DOS REIS  9.654908e+10  67991604545    6735214704
# 425               ANA ALVES DE SOUZA  9.708393e+10  67996716809   67981467261
# 426     JOCELY PEREIRA MENDES DUARTE  9.912510e+10  67998915710   67981654969
#
# [427 rows x 4 columns]

# %%
#leitura da tabela
import pandas as pd
tabela = pd.read_excel("carteira ruan indicacao cartao santander18.01 427 nomes.xlsx")

#cpf variavel   "coluna"
for i, cpf in enumerate(tabela["CPF"]):
    telefone = i, (tabela["TELEFONE 2"])
    #paigina web
    from selenium import webdriver

    navegador = webdriver.Chrome()
    navegador.get("https://www.abrasuacontasnt.com.br/indicacoes")

    #CLICK CARTAO
    navegador.find_element_by_xpath('//*[@id="forme-form"]/div[1]/div[2]/label/span').click()

    #CLICK CORRESPONDENTE 
    navegador.find_element_by_xpath('//*[@id="forme-form"]/div[3]/div[2]/label/span').click()
    #LOJA
    navegador.find_element_by_xpath('//*[@id="codigoCorrespondente"]').send_keys('54254')
    
     #MEU CPF
    navegador.find_element_by_xpath('//*[@id="CPFSocio"]').send_keys('014.794.541-09')
    #CPF DO CLIENTE 
    navegador.find_element_by_xpath('//*[@id="CPF"]').send_keys(cpf)

        #TELEFONE DO CLIENTE 
    navegador.find_element_by_xpath('//*[@id="Telefone"]').send_keys(str(telefone))
       
        
    #TERMOS
    navegador.find_element_by_xpath('//*[@id="AceitaPoliticas"]').click()
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12828/4140822899.py in <module>
#       9     from selenium import webdriver
#      10
# ---> 11     navegador = webdriver.Chrome()
#      12     navegador.get("https://www.abrasuacontasnt.com.br/indicacoes")
#      13
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      68             service = Service(executable_path, port, service_args, service_log_path)
#      69
# ---> 70         super(WebDriver, self).__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      71                                         port, options,
#      72                                         service_args, desired_capabilities,
#
# ...

# %%
#cpf variavel   "coluna"
for i, cpf in enumerate(tabela["CPF"]):
    telefone = i, (tabela["TELEFONE 2"])
    print(cpf)
# Out:
# 1394752571.0
# 1395703574.0
# 1395906173.0
# 1396109528.0
# 1396141502.0
# 1396184570.0
# 1396482598.0
# 1396814507.0
# 1396875565.0
# 1396907513.0
# 13970607515.0
# 1397191562.0
# 1397415509.0
# 13982164885.0
# 139827536.0
# 13985345520.0
# 1398964573.0
# 1399001523.0
# 139905510.0
# 13991779587.0
# 1399385593.0
# 1399621823.0
# 1399712543.0
# 1399775545.0
# 1399902598.0
# 1400420598.0
# 1400715555.0
# 1400728533.0
# 1400929512.0
# 1402210507.0
# 14023015881.0
# 1402631529.0
# 1403402540.0
# 1403410569.0
# 1403417571.0
# 1403629595.0
# 1404265589.0
# 1404287558.0
# 140431578.0
# 1404394559.0
# 1404424563.0
# 1404614508.0
# 1404744550.0
# 1405130512.0
# 1405302585.0
# 1405443138.0
# 1406115509.0
# 1406133582.0
# 140616519.0
# 1406189103.0
# 1406271543.0
# 1406577545.0
# 140659595.0
# 1406599514.0
# 14067933703.0
# 1407420500.0
# 140742573.0
# 14075346706.0
# 1407597.0
# 14078945520.0
# 1408238594.0
# 140836551.0
# 1408457555.0
# 140896538.0
# 1409164586.0
# 140944524.0
# ...
